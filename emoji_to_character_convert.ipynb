# %% [markdown]
# ### job completed visite google sheet
#
# 1.job was to calculate all emoji in each row where each row was populated with  text <br>
# 2.then use another file containing emoji in one column and there descripation in next column<br>
# 3.replace emojis with there description 🙂 with [happy] but only replace those which are given in another xlsx file<br>
#
# **given two files**<br>
# https://docs.google.com/spreadsheets/d/1m2UGO0ekeiFipP3P58ziKy6tdhU79eKP67rgFTLyAUo/edit#gid=1742094466
# https://docs.google.com/spreadsheets/d/1iSuZZZMSENlnQmgEcTkmueKx-w_FmvsIY8ZfmnC14wM/edit#gid=510769358
#
# **end result after cleaning data :**<br>
# https://docs.google.com/spreadsheets/d/1BLV5rhLz_MrvUBtEKkuxe201sh12NQV-Ylq9Eu9DQBw/edit#gid=544890868

# %%
import pandas as pd
import re
import emoji
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 30)

pd.options.display.max_colwidth=50

# %%
data=pd.read_excel('D:\\Twitter Comments.xlsx')
data['Text'].head(10)
# Out:
# 0    #RETENCIÓN nivel NEGRO en #C37 (pk 20.7 al 42 ...
# 1    #RETENCIÓN nivel NEGRO en #T201 (pk 6 al 16 am...
# 2    #VEH_ACCIDENTADO nivel AMARILLO en AUTOPISTA /...
# 3    #RETENCIÓN nivel NEGRO en #T243 (pk 7 al 12 am...
# 4    #RETENCIÓN nivel NEGRO en #T224 (pk 2 al 8 amb...
# 5    #RETENCIÓN nivel NEGRO en #TV2241 (pk 0 al 4 a...
# 6    #RETENCIÓN nivel NEGRO en #TP2442 (pk 12 al 0 ...
# 7    #RETENCIÓN nivel NEGRO en #TV2443 (pk 1 al 17 ...
# 8    #justsold\n\nIf you or someone you know wants ...
# 9    RT @InformacionDGT: #VEH_ACCIDENTADO nivel AMA...
# Name: Text, dtype: object

# %%
h=[x for x in emoji.UNICODE_EMOJI.keys()]
h=' '.join(h)
h
# Out:
# '🥇 🥈 🥉 🆎 🏧 🅰 🇦🇫 🇦🇱 🇩🇿 🇦🇸 🇦🇩 🇦🇴 🇦🇮 🇦🇶 🇦🇬 ♒ 🇦🇷 ♈ 🇦🇲 🇦🇼 🇦🇨 🇦🇺 🇦🇹 🇦🇿 🔙 🅱 🇧🇸 🇧🇭 🇧🇩 🇧🇧 🇧🇾 🇧🇪 🇧🇿 🇧🇯 🇧🇲 🇧🇹 🇧🇴 🇧🇦 🇧🇼 🇧🇻 🇧🇷 🇮🇴 🇻🇬 🇧🇳 🇧🇬 🇧🇫 🇧🇮 🆑 🆒 🇰🇭 🇨🇲 🇨🇦 🇮🇨 ♋ 🇨🇻 ♑ 🇧🇶 🇰🇾 🇨🇫 🇪🇦 🇹🇩 🇨🇱 🇨🇳 🇨🇽 🎄 🇨🇵 🇨🇨 🇨🇴 🇰🇲 🇨🇬 🇨🇩 🇨🇰 🇨🇷 🇭🇷 🇨🇺 🇨🇼 🇨🇾 🇨🇿 🇨🇮 🇩🇰 🇩🇬 🇩🇯 🇩🇲 🇩🇴 🔚 🇪🇨 🇪🇬 🇸🇻 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000
# [c for c in ii if c in emoji.UNICODE_EMOJI]
filter1=re.sub(fr"[^{h}]+",'',string_text)
re.sub(r'[#0-9]','',filter1)
# Out:
# '                                                                                                                         🏡      📞                                                                                                                                                  😱😱                                                                                                                  ➡       🛵                                                                                    🥉                 📱                                                                                                                                                       ️⃣️⃣️⃣       👍       ⬇️⬇️ 👉                                                    📱                😡                                                                                                                                                                                                                                                      
# ...

# %%
def takeout(x):
    y=re.sub(fr"[^{h}]+",'',x)
    y=re.sub(r'([#0-9 *]+)|(\u200d)+','',y)
#     y=re.sub(r'[*]+|(\U0001f971)+','',y)
    return y
data['emoji']=data['Text'].apply(takeout)

# %%
data['emoji'].values.tolist()
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '🏡📞',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '😱😱',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '➡🛵',
#  '',
#  '',
#  '',
#  '',
#  '🥉',
#  '📱',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '️⃣️⃣️⃣👍⬇️⬇️👉',
#  '',
#  '',
#  '',
#  '📱',
#  '😡',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '🥉',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '🥉',
#  '',
#  '',
#  '🥉',
#  '',
#  '🥉',
#  '',
#  '🥉',
#  '🥉',
#  '🥉',
#  '🥉',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '✋🏼🤚🏼⛔️',
#  '',
#  '',
#  '',
#  '👉',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '🛸🛸➡️➡️➡️',
#  '',
#  '🛴',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
data.loc[7895,:]
# Out:
# Text     WAO WAO WAOOOO mis chicos BAYAHIBE!!! Duro dur...
# emoji                                👏🏽👏🏽👏🏽👏🏽👏🏽❤️❤️❤️✍🏼️💪🏼
# Name: 7895, dtype: object

# %%
''.join(data.loc[:,'emoji'].values.tolist())
# Out:
# '🏡📞😱😱➡🛵🥉📱️⃣️⃣️⃣👍⬇️⬇️👉📱😡🥉🥉🥉🥉🥉🥉🥉🥉✋🏼🤚🏼⛔️👉🛸🛸➡️➡️➡️🛴➡️🗣🇩🇴✌🏼🇩🇴🤷♀🤷♂🤷♀🤷♂️⃣️⃣️⃣👍⬇️⬇️👉😂😂✌🏼👀😊👍🏼👉🏼️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉🤨🎶👰🏼😩😩⚠️🥵🔹✌🏼👧🏼😉😉💬️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉😉👩🏫👨🏫️⃣️⃣️⃣👍⬇️⬇️👉😍😍😍️⃣️⃣️⃣👍⬇️⬇️👉️⃣️⃣️⃣👍⬇️⬇️👉😔👧🏼📵📵✌🏼👀💭😂😂😂🏍🇩🇴✌🏼😂😂🎤🎼💛😏✌🏼😓😪✌🏼🙌🏼✌🏼🏃🏻♀️🔥🔥😍😍😍😍😔😞💔😢😔😔😔😔😔😔😩😩😪😩😩😔🤷🤦🏻♀️😪😒😪😔😔😔😔😔😔😪😢🇩🇴🙄🙄🙄😞💔😞💔👀💭😂😂😂👌
print('emoji in total :'+ str(len(em_count)))
# Out:
# emoji in total :8900

# %%
data.iloc[355:700,:]
# Out:
#                                                   Text         emoji
# 355  #OBRAS nivel ROJO en #AP68 (pk 28) AMURRIO #DG...
# 356  RT @guardiacivil: A partir de 1️⃣,3️⃣5️⃣  de a...  ️⃣️⃣️⃣👍⬇️⬇️👉
# 357  Anyone else affected by these technical proble...
# 358  #OBRAS nivel AMARILLO en AUTOPISTA / AUTOVÍA #...
# 359  #OBRAS nivel NEGRO en #TV7003 (pk 0.1 al 0.1 a...
# ..                                                 ...           ...
# 695                               Dando grito 😭😭😭 #dgt           😭😭😭
# 696  El trabalenguas no debe pasar.  #DominicanasGo...
# 697  Mielda se va el chamaquito xD #DominicanasGotT...
# 698  Yo en los recortes #dominicanasgottalent https...
# 699  RT @TrinaNeri: Coñoooo me hicieron llorar con ...            😩😩
#
# [345 rows x 2 columns]

# %% [markdown]
# ### Replacing emojis in text colum  with given corrosponding character

# %%
emoji=pd.read_excel('D:\\emoji table (1).xlsx')
emoji[['Unnamed: 0','Unnamed: 2']]
# Out:
#    Unnamed: 0      Unnamed: 2
# 0           😁       [Amused ]
# 1           😂         [Funny]
# 2           😃     [Happiness]
# 3           😄     [Happiness]
# 4           😅         [Whew!]
# 5           😆    [excitement]
# 6           😉       [playful]
# 7           😊     [Happiness]
# 8           😋     [delicious]
# 9           😌         [peace]
# 10          😍          [Love]
# 11          😏    [flirtation]
# 12          😒   [displeasure]
# 13          😓       [sadness]
# 14          😔  [disappointed]
# 15          😖   [frustration]
# 16          😘          [Love]
# 17          😚          [Love]
# 18          😜           [fun]

# %%
def fun0(x):
    for em in emoji['Unnamed: 0'].values.tolist():
        if em in x:
            cha=emoji.loc[emoji['Unnamed: 0']==em,'Unnamed: 2']
            x=x.replace(em,str(str(cha.tolist()[0])))
            
    return x
data['new']=data['Text'].apply(fun0)

# %% [markdown]
# #### emoji replaced by character description

# %%
data.iloc[355:700,:]
# Out:
#                                                   Text         emoji  \
# 355  #OBRAS nivel ROJO en #AP68 (pk 28) AMURRIO #DG...
# 356  RT @guardiacivil: A partir de 1️⃣,3️⃣5️⃣  de a...  ️⃣️⃣️⃣👍⬇️⬇️👉
# 357  Anyone else affected by these technical proble...
# 358  #OBRAS nivel AMARILLO en AUTOPISTA / AUTOVÍA #...
# 359  #OBRAS nivel NEGRO en #TV7003 (pk 0.1 al 0.1 a...
# ..                                                 ...           ...
# 695                               Dando grito 😭😭😭 #dgt           😭😭😭
# 696  El trabalenguas no debe pasar.  #DominicanasGo...
# 697  Mielda se va el chamaquito xD #DominicanasGotT...
# 698  Yo en los recortes #dominicanasgottalent https...
# 699  RT @TrinaNeri: Coñoooo me hicieron llorar con ...            😩😩
#
#                                                    new
# 355  #OBRAS nivel ROJO en #AP68 (pk 28) AMURRIO #DG...
# 356  RT @guardiacivil: A partir de 1️⃣,3️⃣5️⃣  de a...
# 357  Anyone else affected by these technical proble...
# ...

# %%
data.to_excel('D:\\cleaned emoji text.xlsx')
