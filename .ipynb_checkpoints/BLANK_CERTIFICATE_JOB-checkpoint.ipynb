# %%
from PIL import Image
import pandas as pd

# %%
im=Image.open("D:\\certificate_blank.jpg")

# %%
data=pd.read_excel('D:\\banquet.xlsx')
data
# Out:
#    Banquet         Team First Name   Last Name  Grade
# 0        n          9th      Ryan      Blokzyl      9
# 1        n          9th      Dante        Dade      9
# 2        n          9th      Dylan       Jones      9
# 3        n          9th        Sid    Veeranki      9
# 4        n          9th     Samual        Wood      9
# 5        n  Jr. Varsity      Kobie       Brown     10
# 6        n      Varsity     Matteo    Carriere     10
# 7        y          9th     Pierre         Aka      9
# 8        y          9th     Carson     Frissel      9
# 9        y          9th       Josh       James      9
# 10       y          9th    Michael    Serafino      9
# 11       y          9th       Josh       Unger      9
# 12       y          9th    Cameron       Woods      9
# 13       y          9th     Jaden        Young      9
# 14       y  Jr. Varsity    Ahmadou      Diallo     10
# 15       y  Jr. Varsity      Hamza      Eldeib     10
# ...

# %%
draw = ImageDraw.Draw(im)
fontsize = 100
fnt = ImageFont.truetype("D:\\alex-brush\\AlexBrush-Regular.ttf",100)
draw.text((400-20,1114-100), "Up Work", font=fnt, fill=(4,139,34,0))
# draw text, full opacity
draw.text((1340-80,1067-50), "Python Job", font=fnt, fill=(4,139,34,0))

# %%
print(draw)

# %%
im.save('D:\\abcdefg', "PNG")

# %%
PIL.Image.open("D:\\abcdefg")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x1545 at 0x137953E7908>
